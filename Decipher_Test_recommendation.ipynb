# %%
#Importing the necessary libraries
import json
import numpy as np
import pandas as pd

# %%
#Reading the json file's
import json

with open('students.json',encoding="utf8") as f:
  data = json.load(f)

with open('tests_details.json',encoding="utf8") as f:
  test_details = json.load(f)


with open('test_submissions.json',encoding="utf8") as f:
  test_submission = json.load(f)

# %%
len(test_details)
# Out:
# 876

# %%
len(test_submission)
# Out:
# 3589

# %%
Different_super_groups=[]  # A list to contain all the different supergroups

# %%
# To find all the different supergroups in which students are enrolled
for i in range(0,10000):
  try:
    for k in data[i]['target_super_groups']:
      Different_super_groups.append(k['title'][0]['value'])
  except:
    continue

# %%
# To print only the unique elements of a list
def unique(list1): 
    x = np.array(list1) 
    print(np.unique(x))

# %%
unique(Different_super_groups) # The Different supergroups we have
# Out:
# ['Banking Exams' 'Defence Exams' 'Engineering Recruitment Exams'
#  'Insurance Exams' 'Other Govt. Exams' 'Police Exams'
#  'Professional Skills' 'Railways Exams' 'SSC Exams' 'State Govt. Exams'
#  'Teaching Exams']

# %%
#Different lists to store the students enrolled in different supergroups
Defence_Exams=[]
Engineering_Recruitment_Exams=[]
Insurance_Exams=[]
Other_Govt_Exams=[]
Police_Exams=[]
Professional_Skills=[]
Railways_Exams=[]
SSC_Exams=[]
State_Govt_Exams=[]
Teaching_Exams=[]
Banking_Exams=[]

# %%
# If else condition to appends the students in the list in which supergoup they are enrolled
for i in range(0,10000):
  try:
    for k in data[i]['target_super_groups']:
      if(k['title'][0]['value']== 'Banking Exams'):
        Banking_Exams.append(data[i]['sid'])
      if(k['title'][0]['value']== 'Defence Exams'):
        Defence_Exams.append(data[i]['sid'])
      if(k['title'][0]['value']== 'Engineering Recruitment Exams'):
        Engineering_Recruitment_Exams.append(data[i]['sid'])
      if(k['title'][0]['value']== 'Insurance Exams'):
        Insurance_Exams.append(data[i]['sid'])
      if(k['title'][0]['value']== 'Other Govt. Exams'):
        Other_Govt_Exams.append(data[i]['sid'])
      if(k['title'][0]['value']== 'Police Exams'):
        Police_Exams.append(data[i]['sid'])
      if(k['title'][0]['value']== 'Professional Skills'):
        Professional_Skills.append(data[i]['sid'])
      if(k['title'][0]['value']== 'Railways Exams'):
        Railways_Exams.append(data[i]['sid'])
      if(k['title'][0]['value']== 'SSC Exams'):
        SSC_Exams.append(data[i]['sid'])
      if(k['title'][0]['value']== 'State Govt. Exams'):
        State_Govt_Exams.append(data[i]['sid'])
      if(k['title'][0]['value']== 'Teaching Exams'):
        Teaching_Exams.append(data[i]['sid'])
  except:
    continue

# %%
# List to store all the tests to the supergroup for which they are for
Defence_Exams_test=[]
Engineering_Recruitment_Exams_test=[]
Insurance_Exams_test=[]
Other_Govt_Exams_test=[]
Police_Exams_test=[]
Professional_Skills_test=[]
Railways_Exams_test=[]
SSC_Exams_test=[]
State_Govt_Exams_test=[]
Teaching_Exams_test=[]
Banking_Exams_test=[]

# %%
for i in range(0,876):
  try:
    exam=test_details[i]['target'][0]['title'][0]['value']
    if exam=='AFCAT' or exam=="AMCAT" or exam == 'Airforce Group X' or exam == 'Airforce Group Y' or exam== 'CDS' or exam == 'CISF Constable' or exam == 'DRDO MTS' or exam=='Navy AA' or exam =='Navy SSR' or exam == 'Navy MR' or exam =='NDA':
      Defence_Exams_test.append(test_details[i]['test_id'])
    if exam =='AP Police Constable' or exam == 'Bihar Police ASI Steno' or exam =='Bihar Police Constable' or exam == 'Bihar Police SI' or exam == 'Rajasthan Police Constable' or exam=='Bihar Police Forest Guard' or exam == 'Delhi Police Constable' or exam == 'Delhi Police Head Constable' or exam =='Haryana Police Constable' or exam=='MP Jail Prahari' or exam=='UP Police Constable' or exam=='UP Police Jail Warder' or exam=='UP Police Sub Inspector' or exam=='UPSC CAPF AC':
      Police_Exams_test.append(test_details[i]['test_id'])
    if exam=='APSC Assistant Engineer' or exam == 'ECIL CS' or exam =='GATE CE' or exam =='GATE EC' or exam=='GATE CS' or exam=='GATE EE' or exam=='GATE ME' or exam=='ISRO Scientist CS' or exam =='ISRO Scientist EC' or exam =='ISRO Technical Assistant' or exam=='ISRO Technician' or exam=='MPTET' or exam=='RCFL' or exam=='NLC Graduate Executive Trainee' or exam=='rcfl' or exam=='TCS' or exam=='UPPCL Assistant Engineer' or exam=='UPPSC AE' or exam=='UPRVUNL AE' or exam=='Vizag Steel Management Trainee' or exam=='UPSC IES':
      Engineering_Recruitment_Exams_test.append(test_details[i]['test_id'])
    if exam =='CTET' or exam=='Bihar STET' or exam=='REET' or exam=='TN TRB CS' or exam=='UGC NET':
      Teaching_Exams_test.append(test_details[i]['test_id'])
    if exam=='Bank of Baroda PO' or exam== 'IBPS SO' or exam=='IBPS Clerk' or exam=='IBPS PO' or exam =='J&K Bank Clerk' or exam== 'RBI Assistant' or exam== 'RBI Grade B' or exam =='RRB Officer Scale - I' or exam=='RRC Group D' or exam=='SBI Clerk' or exam =='SBI PO' or exam =='SBI SO' or exam=='SEBI Grade A':
      Banking_Exams_test.append(test_details[i]['test_id'])
    if exam == 'CWC Junior Superintendent' or exam=='FCI Manager' or exam=='NBE':
      Other_Govt_Exams_test.append(test_details[i]['test_id'])
    if exam == 'Current Affairs' or exam =='English' or exam=='Skill Courses':
      Professional_Skills_test.append(test_details[i]['test_id'])
    if exam ==  'DDA Patwari' or exam == 'DSSSB' or exam=='HSSC Group D' or exam== 'MP Patwari' or exam=='REET' or exam=='RRB Office Assistant' or exam=='RRC Group D' or exam=='RSMSSB JE' or exam=='Rajasthan Patwari' or exam=='UP Lekhpal' or  exam=='UPPCL Technician' or exam=='UPPCS':
      State_Govt_Exams_test.append(test_details[i]['test_id'])
    if exam=='DMRC Maintainer' or exam=='RRB ALP' or exam=='RRB NTPC' or exam=='RRB JE':
      Railways_Exams_test.append(test_details[i]['test_id'])
    if exam =='LIC AAO' or exam == 'LIC Assistant' or exam=='NIACL AO' or exam=='UPSC EPFO':
      Insurance_Exams_test.append(test_details[i]['test_id'])
    if exam == 'IT Officer - Scale I' or exam=='SSC CGL' or exam=='SSC CHSL' or exam=='SSC CPO' or exam=='SSC GD Constable' or exam=='SSC JE CE' or exam=='SSC JE EE' or exam== 'SSC JE ME'or exam=='SSC JHT' or exam=='SSC MTS' or exam=='SSC Selection Post' or exam=='SSC Stenographer':
      SSC_Exams_test.append(test_details[i]['test_id'])
  except:
    continue

# %%
All_tests=[]

# %%
for i in range(0,876):
  All_tests.append(test_details[i]['test_id'])

# %%
test_taken=[]

# %%
# To store the test taken in the list
for i in range(0,3589):
  try:
     test_taken.append(test_submission[i]['testId'])
  except:
     continue

# %%
Defence_course_count=[]
Engineering_Recruitment_course_count=[]
Insurance_course_count=[]
Other_Govt_course_count=[]
Police_course_count=[]
Professional_Skills_course_count=[]
Railways_course_count=[]
SSC_course_count=[]
State_Govt_course_count=[]
Teaching_course_count=[]
Banking_course_count=[]

# %%
All_tests_count=[]  #To count for all the tests

# %%
# To count number of times each test has been taken to set the priority
for j in Defence_Exams_test:
  Defence_course_count.append(test_taken.count(j))

for j in Engineering_Recruitment_Exams_test:
  Engineering_Recruitment_course_count.append(test_taken.count(j))

for j in Insurance_Exams_test:
  Insurance_course_count.append(test_taken.count(j))

for j in Other_Govt_Exams_test:
  Other_Govt_course_count.append(test_taken.count(j))

for j in Police_Exams_test:
  Police_course_count.append(test_taken.count(j))                                 

for j in Professional_Skills_test:
  Professional_Skills_course_count.append(test_taken.count(j))

for j in Railways_Exams_test:
  Railways_course_count.append(test_taken.count(j))

for j in SSC_Exams_test:
  SSC_course_count.append(test_taken.count(j))

for j in State_Govt_Exams_test:
  State_Govt_course_count.append(test_taken.count(j))


for j in Teaching_Exams_test:
  Teaching_course_count.append(test_taken.count(j))

for j in Banking_Exams_test:
  Banking_course_count.append(test_taken.count(j))

# %%
for j in All_tests:
  All_tests_count.append(test_taken.count(j))

# %%
Defence_Exams_course = pd.DataFrame({'All_courses':Defence_Exams_test,'Count':Defence_course_count})
Engineering_Recruitment_Exams_course = pd.DataFrame({'All_courses':Engineering_Recruitment_Exams_test,'Count':Engineering_Recruitment_course_count})
Insurance_Exams_course = pd.DataFrame({'All_courses':Insurance_Exams_test,'Count':Insurance_course_count})
Other_Govt_Exams_course = pd.DataFrame({'All_courses':Other_Govt_Exams_test,'Count':Other_Govt_course_count})
Police_Exams_course = pd.DataFrame({'All_courses':Police_Exams_test,'Count':Police_course_count})
Professional_Skills_course = pd.DataFrame({'All_courses':Professional_Skills_test,'Count':Professional_Skills_course_count})
Railways_Exams_course= pd.DataFrame({'All_courses':Railways_Exams_test,'Count':Railways_course_count})
SSC_Exams_course = pd.DataFrame({'All_courses':SSC_Exams_test,'Count':SSC_course_count})
State_Govt_Exams_course = pd.DataFrame({'All_courses':State_Govt_Exams_test,'Count':State_Govt_course_count})
Teaching_Exams_course = pd.DataFrame({'All_courses':Teaching_Exams_test,'Count':Teaching_course_count})
Banking_Exams_course = pd.DataFrame({'All_courses':Banking_Exams_test,'Count':Banking_course_count})

# %%
All_courses = pd.DataFrame({'All_courses':All_tests,'Count': All_tests_count})

# %%
Defence_Exams_course =Defence_Exams_course.sort_values(by ='Count', ascending=False, inplace=False)
Engineering_Recruitment_Exams_course = Engineering_Recruitment_Exams_course.sort_values(by ='Count', ascending=False, inplace=False)
Insurance_Exams_course = Insurance_Exams_course.sort_values(by ='Count', ascending=False, inplace=False)
Other_Govt_Exams_course = Other_Govt_Exams_course.sort_values(by ='Count', ascending=False, inplace=False)
Police_Exams_course  = Police_Exams_course.sort_values(by ='Count', ascending=False, inplace=False)
Professional_Skills_course= Professional_Skills_course.sort_values(by ='Count', ascending=False, inplace=False)
Railways_Exams_course    = Railways_Exams_course.sort_values(by ='Count', ascending=False, inplace=False)
SSC_Exams_course     = SSC_Exams_course.sort_values(by ='Count', ascending=False, inplace=False)
State_Govt_Exams_course = State_Govt_Exams_course.sort_values(by ='Count', ascending=False, inplace=False)
Teaching_Exams_course  = Teaching_Exams_course .sort_values(by ='Count', ascending=False, inplace=False)
Banking_Exams_course = Banking_Exams_course.sort_values(by ='Count', ascending=False, inplace=False)

# %%
All_courses = All_courses.sort_values(by ='Count', ascending=False, inplace=False)

# %%
query=input()
m=0
Recommendation=[]
m=[]
if query in Banking_Exams:
  index = Banking_Exams_course.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if Banking_Exams_course.iloc[i,0] not in m:
      Recommendation.append(Banking_Exams_course.iloc[i,0])
      break;
if query in Defence_Exams:
  index = Defence_Exams_course.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if Defence_Exams_course.iloc[i,0] not in m:
      Recommendation.append(Defence_Exams_course.iloc[i,0])
      break;
if query in Engineering_Recruitment_Exams:
  index = Engineering_Recruitment_Exams_course.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if Engineering_Recruitment_Exams_course.iloc[i,0] not in m:
      Recommendation.append(Engineering_Recruitment_Exams_course.iloc[i,0])
      break;
if query in Insurance_Exams:
  index = Insurance_Exams_course.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if Insurance_Exams_course.iloc[i,0] not in m:
      Recommendation.append(Insurance_Exams_course.iloc[i,0])
      break;
if query in Police_Exams:
  index = Police_Exams_course.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if Police_Exams_course.iloc[i,0] not in m:
      Recommendation.append(Police_Exams_course.iloc[i,0])
      break;
if query in Professional_Skills:
  index = Professional_Skills_course.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if Professional_Skills_course.iloc[i,0] not in m:
      Recommendation.append(Professional_Skills_course.iloc[i,0])
      break;
if query in Railways_Exams:
  index = Railways_Exams_course.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if Railways_Exams_course.iloc[i,0] not in m:
      Recommendation.append(Railways_Exams_course.iloc[i,0])
      break;
if query in SSC_Exams:
  index = SSC_Exams_course.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if SSC_Exams_course.iloc[i,0] not in m:
      Recommendation.append(SSC_Exams_course.iloc[i,0])
      break;
if query in State_Govt_Exams:
  index = State_Govt_Exams_course.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if State_Govt_Exams_course.iloc[i,0] not in m:
      Recommendation.append(State_Govt_Exams_course.iloc[i,0])
      break;
if len(Recommendation)==0:
  index = All_courses.index
  number_of_rows = len(index)
  for i in range(0,number_of_rows):
    if All_courses.iloc[i,0] not in m:
      Recommendation.append(All_courses.iloc[i,0])
      break;


print("The recommended courses are\n")
for i in Recommendation:
  print(i)
# Out:
# The recommended courses are
#
# c0ece24d2d5c3893c5c96b8d645fcc92

# %%
data
# Out:
# [{'sid': '6e6dabfe6d4eaa2d15b4672e0d0fad5a',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'a4839004275f9f0583a20f03a8b759c3',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'bd73581ef03a1f15f24a7d2c7b573792',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': '7a3595d03ba05f3778ade4e0881be40f',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'ee2dce155a659d3b6594479d228e98b8',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': '7a86b26e3aa2d8de01752db4691b1777',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'b1857a4ed7b82eb0208bcdc251dc87d3',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'e4b58b515ef2b64805258a375f6931c6',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'ffe7c33ba8e1873d96407a56140b1299',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'b79e8439cffb431fc35a887c264650a2',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'bda08d31d140794312adb1fcd300d704',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': '15ff4ec766d3cf9d3f10d02d8e588dd8',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'a3ef8104144c540fe410da9a51369cd5',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': '1fd0e2cd986da1d20abc03bb23d6ba91',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': '409c54b2e7e3e18bee6c8da7a212474a',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': 'bed8ed79a9f38ca992c89bb7a328ce07',
#   'targets': [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba',
#     'title': [{'language': 'English', 'value': 'GATE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:25.158+05:30'}],
#   'target_super_groups': [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T14:44:22.585+05:30'}]},
#  {'sid': '4c2656ac2a2eb9168c5db8617d38e365',
#   'targets': [{'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': 'b5dc7859e29e978c0c93d8592dd2a3c0',
#     'title': [{'language': 'English', 'value': 'SSC CHSL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': '267449cef6a69ddba57803a44daea1fa',
#     'title': [{'language': 'English', 'value': 'RRB Officer Scale - I'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': 'a4b3f38ba5a80bc0ccb9d7e2be728229',
#     'title': [{'language': 'English', 'value': 'SBI PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T09:53:07.56+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T09:53:07.56+05:30'},
#    {'_id': '67bcbee6ffd1bf148fc2fb934d55f07e',
#     'title': [{'language': 'English', 'value': 'Railways Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T09:53:07.56+05:30'}]},
#  {'sid': 'c5cf2d43b10205f4c8645ec930a7b061',
#   'targets': [{'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T09:53:07.56+05:30'}]},
#  {'sid': '15124e459c173f28a53b4863fdb8f6b3',
#   'targets': [{'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': 'b5dc7859e29e978c0c93d8592dd2a3c0',
#     'title': [{'language': 'English', 'value': 'SSC CHSL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T09:53:07.56+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T09:53:07.56+05:30'},
#    {'_id': '67bcbee6ffd1bf148fc2fb934d55f07e',
#     'title': [{'language': 'English', 'value': 'Railways Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-10T09:53:07.56+05:30'}]},
#  {'sid': 'dd3fb5b38d49c87597f46c9e390286de',
#   'targets': [{'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': 'b5dc7859e29e978c0c93d8592dd2a3c0',
#     'title': [{'language': 'English', 'value': 'SSC CHSL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': '267449cef6a69ddba57803a44daea1fa',
#     'title': [{'language': 'English', 'value': 'RRB Officer Scale - I'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'},
#    {'_id': 'a4b3f38ba5a80bc0ccb9d7e2be728229',
#     'title': [{'language': 'English', 'value': 'SBI PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:47.207+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'},
#    {'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T11:12:43.796+05:30'},
#    {'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T11:42:29.454+05:30'},
#    {'_id': '67bcbee6ffd1bf148fc2fb934d55f07e',
#     'title': [{'language': 'English', 'value': 'Railways Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:43.968+05:30'},
#    {'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T18:25:43.968+05:30'},
#    {'_id': '09b12737a8cd173b05e9d16e456e8560',
#     'title': [{'language': 'English', 'value': 'Professional Skills'},
#      {'language': 'Hindi', 'value': 'व्यावसायिक कौशल'}],
#     'updatedOn': '2020-09-09T18:25:43.968+05:30'}]},
#  {'sid': 'df7d394748bd8d61230a78252d41b3be',
#   'targets': [{'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'a4b3f38ba5a80bc0ccb9d7e2be728229',
#     'title': [{'language': 'English', 'value': 'SBI PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': '92b100d434c9b9ec738a681c68ee52b5',
#     'title': [{'language': 'English', 'value': 'RPSF'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T17:20:19.31+05:30'},
#    {'_id': 'ce93e65e281ffed2347769d363c25b70',
#     'title': [{'language': 'English', 'value': 'RRB NTPC'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T17:20:19.31+05:30'},
#    {'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T17:20:19.31+05:30'},
#    {'_id': '267449cef6a69ddba57803a44daea1fa',
#     'title': [{'language': 'English', 'value': 'RRB Officer Scale - I'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T17:20:19.31+05:30'},
#    {'_id': '938273f6322e14e3ae2ea70e96855a1f',
#     'title': [{'language': 'English', 'value': 'RRC Group D'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T17:20:19.31+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-09T17:20:19.31+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'},
#    {'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T11:12:43.796+05:30'}]},
#  {'sid': 'dda4d870120a3e879ffdae07766d0431',
#   'targets': [{'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'a4b3f38ba5a80bc0ccb9d7e2be728229',
#     'title': [{'language': 'English', 'value': 'SBI PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'}]},
#  {'sid': 'b3c1fdfe0799954e15eb54a27f8a4d54',
#   'targets': [{'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'a4b3f38ba5a80bc0ccb9d7e2be728229',
#     'title': [{'language': 'English', 'value': 'SBI PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'}]},
#  {'sid': '3e30703dfce3af5b5a8d6d744f8b6199',
#   'targets': [{'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'a4b3f38ba5a80bc0ccb9d7e2be728229',
#     'title': [{'language': 'English', 'value': 'SBI PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'}]},
#  {'sid': 'c786c7e765b8bfc31d2bd3a696b637cc',
#   'targets': [{'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'a4b3f38ba5a80bc0ccb9d7e2be728229',
#     'title': [{'language': 'English', 'value': 'SBI PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'}]},
#  {'sid': '0be11901969c6f63e50b75157889f2b5',
#   'targets': [{'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'}]},
#  {'sid': '86ed5c2e8333d00364b244795a32c83d',
#   'targets': [{'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': 'd659108e88c11114dfccb96aa8225988',
#   'targets': [{'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': 'c883aca5dc77e2bca2042203cf6d4a47',
#   'targets': [{'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'a4b3f38ba5a80bc0ccb9d7e2be728229',
#     'title': [{'language': 'English', 'value': 'SBI PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T20:43:32.719+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'}]},
#  {'sid': '2690bafe9e454371651f3e6816779068',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'},
#    {'_id': '5671296260527d58b8f0b38c79e1f774',
#     'title': [{'language': 'English', 'value': 'SSC JE EE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:22:32.767+05:30'},
#    {'_id': 'ff680031e124ff368641d497b4bbbdd2',
#     'title': [{'language': 'English', 'value': 'Bihar Police SI'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': '3a33dafe92fabb1d210f48951b0317cd',
#     'title': [{'language': 'English', 'value': 'Delhi Police Head Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': '3712244c886f1d5bfa634a4a4b1525de',
#     'title': [{'language': 'English', 'value': 'Delhi Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': 'fcfecddbc2a9a8dc09e03f460cbd181f',
#     'title': [{'language': 'English', 'value': 'UP Police Sub Inspector'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': '3a33dafe92fabb1d210f48951b0317cd',
#     'title': [{'language': 'English', 'value': 'Delhi Police Head Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T19:25:26.421+05:30'},
#    {'_id': '065c0dc33eddd1263fc57eefa310365b',
#     'title': [{'language': 'English', 'value': 'Bihar Police ASI Steno'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T00:19:21.647+05:30'},
#    {'_id': 'fb92bccbada8723f5cfe5ef8a7044771',
#     'title': [{'language': 'English', 'value': 'Bihar Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T00:19:21.647+05:30'},
#    {'_id': '197b126e234d214131385f7a6480670b',
#     'title': [{'language': 'English', 'value': 'AP Police Constable'},
#      {'language': 'Hindi', 'value': 'AP Police Constable'}],
#     'updatedOn': '2020-09-04T00:19:21.647+05:30'},
#    {'_id': '53a43ae1c4c8e99d5e0fb611b9343f86',
#     'title': [{'language': 'English', 'value': 'IB Security Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'e9fae828548a926b3b61cf0c83e611cc',
#     'title': [{'language': 'English', 'value': 'Rajasthan Police SI'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'df9ebc68dc62a4a46f19a1e77209fba4',
#     'title': [{'language': 'English', 'value': 'Delhi Forest Guard'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'e3982307901f966a3020ac8684652fdd',
#     'title': [{'language': 'English', 'value': 'SSC JHT'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': '69b6d649ca5c4d3a10ae70ddd88ddcc8',
#     'title': [{'language': 'English', 'value': 'SSC Selection Post'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'd6424074fbe63ebc318dd438d724ae92',
#     'title': [{'language': 'English', 'value': 'Rajasthan Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'ed80835a69d8c864a395917b3a314f8b',
#     'title': [{'language': 'English', 'value': 'SSC GD Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'd2fbe7905f7f98b8bad4049d937dc090',
#     'title': [{'language': 'English', 'value': 'SSC CPO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'b6175d0fbd66464b9cbfe1142c908e99',
#     'title': [{'language': 'English', 'value': 'SSC Scientific Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'f0cb553bd09b981f4dbca7c0890b108e',
#     'title': [{'language': 'English', 'value': 'Rajasthan Patwari'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': '2d56df559146cc13794bf1b6c763b7d6',
#     'title': [{'language': 'English', 'value': 'English'},
#      {'language': 'Hindi', 'value': 'English'}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': '678e52493d6f118392a01f8883ad1a6a',
#     'title': [{'language': 'English', 'value': 'NBE'},
#      {'language': 'Hindi', 'value': 'NBE'}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'},
#    {'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T11:12:43.796+05:30'}]},
#  {'sid': 'b29bbc7d94cc0ee2cf9b3ad381c7c17a',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'},
#    {'_id': '5671296260527d58b8f0b38c79e1f774',
#     'title': [{'language': 'English', 'value': 'SSC JE EE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:22:32.767+05:30'},
#    {'_id': 'ff680031e124ff368641d497b4bbbdd2',
#     'title': [{'language': 'English', 'value': 'Bihar Police SI'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': '3a33dafe92fabb1d210f48951b0317cd',
#     'title': [{'language': 'English', 'value': 'Delhi Police Head Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': '3712244c886f1d5bfa634a4a4b1525de',
#     'title': [{'language': 'English', 'value': 'Delhi Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': 'fcfecddbc2a9a8dc09e03f460cbd181f',
#     'title': [{'language': 'English', 'value': 'UP Police Sub Inspector'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': '3a33dafe92fabb1d210f48951b0317cd',
#     'title': [{'language': 'English', 'value': 'Delhi Police Head Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T19:25:26.421+05:30'},
#    {'_id': '065c0dc33eddd1263fc57eefa310365b',
#     'title': [{'language': 'English', 'value': 'Bihar Police ASI Steno'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T00:19:21.647+05:30'},
#    {'_id': 'fb92bccbada8723f5cfe5ef8a7044771',
#     'title': [{'language': 'English', 'value': 'Bihar Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T00:19:21.647+05:30'},
#    {'_id': '197b126e234d214131385f7a6480670b',
#     'title': [{'language': 'English', 'value': 'AP Police Constable'},
#      {'language': 'Hindi', 'value': 'AP Police Constable'}],
#     'updatedOn': '2020-09-04T00:19:21.647+05:30'},
#    {'_id': '53a43ae1c4c8e99d5e0fb611b9343f86',
#     'title': [{'language': 'English', 'value': 'IB Security Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'e9fae828548a926b3b61cf0c83e611cc',
#     'title': [{'language': 'English', 'value': 'Rajasthan Police SI'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'df9ebc68dc62a4a46f19a1e77209fba4',
#     'title': [{'language': 'English', 'value': 'Delhi Forest Guard'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'e3982307901f966a3020ac8684652fdd',
#     'title': [{'language': 'English', 'value': 'SSC JHT'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': '69b6d649ca5c4d3a10ae70ddd88ddcc8',
#     'title': [{'language': 'English', 'value': 'SSC Selection Post'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'd6424074fbe63ebc318dd438d724ae92',
#     'title': [{'language': 'English', 'value': 'Rajasthan Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'ed80835a69d8c864a395917b3a314f8b',
#     'title': [{'language': 'English', 'value': 'SSC GD Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'd2fbe7905f7f98b8bad4049d937dc090',
#     'title': [{'language': 'English', 'value': 'SSC CPO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'b6175d0fbd66464b9cbfe1142c908e99',
#     'title': [{'language': 'English', 'value': 'SSC Scientific Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'f0cb553bd09b981f4dbca7c0890b108e',
#     'title': [{'language': 'English', 'value': 'Rajasthan Patwari'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': '2d56df559146cc13794bf1b6c763b7d6',
#     'title': [{'language': 'English', 'value': 'English'},
#      {'language': 'Hindi', 'value': 'English'}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': '678e52493d6f118392a01f8883ad1a6a',
#     'title': [{'language': 'English', 'value': 'NBE'},
#      {'language': 'Hindi', 'value': 'NBE'}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'},
#    {'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T11:12:43.796+05:30'}]},
#  {'sid': '6e27ce53a0f7a9c8e090e675e838073e',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'},
#    {'_id': '5671296260527d58b8f0b38c79e1f774',
#     'title': [{'language': 'English', 'value': 'SSC JE EE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:22:32.767+05:30'},
#    {'_id': 'ff680031e124ff368641d497b4bbbdd2',
#     'title': [{'language': 'English', 'value': 'Bihar Police SI'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': '3a33dafe92fabb1d210f48951b0317cd',
#     'title': [{'language': 'English', 'value': 'Delhi Police Head Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': '3712244c886f1d5bfa634a4a4b1525de',
#     'title': [{'language': 'English', 'value': 'Delhi Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': 'fcfecddbc2a9a8dc09e03f460cbd181f',
#     'title': [{'language': 'English', 'value': 'UP Police Sub Inspector'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:38:40.41+05:30'},
#    {'_id': '3a33dafe92fabb1d210f48951b0317cd',
#     'title': [{'language': 'English', 'value': 'Delhi Police Head Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T19:25:26.421+05:30'},
#    {'_id': '065c0dc33eddd1263fc57eefa310365b',
#     'title': [{'language': 'English', 'value': 'Bihar Police ASI Steno'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T00:19:21.647+05:30'},
#    {'_id': 'fb92bccbada8723f5cfe5ef8a7044771',
#     'title': [{'language': 'English', 'value': 'Bihar Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T00:19:21.647+05:30'},
#    {'_id': '197b126e234d214131385f7a6480670b',
#     'title': [{'language': 'English', 'value': 'AP Police Constable'},
#      {'language': 'Hindi', 'value': 'AP Police Constable'}],
#     'updatedOn': '2020-09-04T00:19:21.647+05:30'},
#    {'_id': '53a43ae1c4c8e99d5e0fb611b9343f86',
#     'title': [{'language': 'English', 'value': 'IB Security Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'e9fae828548a926b3b61cf0c83e611cc',
#     'title': [{'language': 'English', 'value': 'Rajasthan Police SI'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'df9ebc68dc62a4a46f19a1e77209fba4',
#     'title': [{'language': 'English', 'value': 'Delhi Forest Guard'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'e3982307901f966a3020ac8684652fdd',
#     'title': [{'language': 'English', 'value': 'SSC JHT'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': '69b6d649ca5c4d3a10ae70ddd88ddcc8',
#     'title': [{'language': 'English', 'value': 'SSC Selection Post'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'd6424074fbe63ebc318dd438d724ae92',
#     'title': [{'language': 'English', 'value': 'Rajasthan Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'ed80835a69d8c864a395917b3a314f8b',
#     'title': [{'language': 'English', 'value': 'SSC GD Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'd2fbe7905f7f98b8bad4049d937dc090',
#     'title': [{'language': 'English', 'value': 'SSC CPO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'b6175d0fbd66464b9cbfe1142c908e99',
#     'title': [{'language': 'English', 'value': 'SSC Scientific Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': 'f0cb553bd09b981f4dbca7c0890b108e',
#     'title': [{'language': 'English', 'value': 'Rajasthan Patwari'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': '2d56df559146cc13794bf1b6c763b7d6',
#     'title': [{'language': 'English', 'value': 'English'},
#      {'language': 'Hindi', 'value': 'English'}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'},
#    {'_id': '678e52493d6f118392a01f8883ad1a6a',
#     'title': [{'language': 'English', 'value': 'NBE'},
#      {'language': 'Hindi', 'value': 'NBE'}],
#     'updatedOn': '2020-09-08T17:55:42.967+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'},
#    {'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T11:12:43.796+05:30'}]},
#  {'sid': '01ceb3a7abd5a779a1e5402d3e92ffba',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': 'b12bad50096c6f9ba3cd3f0df1add28c',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': '1e5e55b5ebbf83caa2274e698a686d95',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': 'c5db4dbd99d0d75ae98ab1e5c20f4980',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': 'ead25aedfa2ba21770f3da15b8b9b002',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'},
#    {'_id': '5671296260527d58b8f0b38c79e1f774',
#     'title': [{'language': 'English', 'value': 'SSC JE EE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:22:32.767+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:06:24.06+05:30'}]},
#  {'sid': '7a2cd2b532ca138af5b6df902c49db2f',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': 'fd00ae274371d13e12d34240cc441c00',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': '353d7ed87613333702f4d29244ed8aec',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': '9f660db36d1cb0a00a9b600d5b61bc62',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': '3fe279f521fb33ad76a69d10a71ce945',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'},
#    {'_id': '5671296260527d58b8f0b38c79e1f774',
#     'title': [{'language': 'English', 'value': 'SSC JE EE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:22:32.767+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': 'b1e0d34972a3e33b9065cc4f8c852110',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': '384f66429218fe2e6745a03483538991',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': 'f091e81050dacb0fe60157efb1f92ea2',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': '20255c5121e92e21889301095489be4f',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
#     'title': [{'language': 'English', 'value': 'RRB Office Assistant'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-03T17:16:20.382+05:30'}],
#   'target_super_groups': [{'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-09-04T10:04:16.851+05:30'}]},
#  {'sid': '051cb9523459b704c94bb6d240b6fc3a',
#   'targets': [{'_id': '5e85dcf35732f4a71776033551e00ca4',
# ...
#     'title': [{'language': 'English', 'value': 'Rajasthan Patwari'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '9819507ac598f457200e1c3656b73f6e',
#     'title': [{'language': 'English', 'value': 'IB ACIO Grade - II'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': 'e9fae828548a926b3b61cf0c83e611cc',
#     'title': [{'language': 'English', 'value': 'Rajasthan Police SI'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '13d3af1e81316b23d69de37fd93ea8f5',
#     'title': [{'language': 'English', 'value': 'RSMSSB JE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '5671296260527d58b8f0b38c79e1f774',
#     'title': [{'language': 'English', 'value': 'SSC JE EE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '9ed77d9acfeaac2688e99b6e061b5873',
#     'title': [{'language': 'English', 'value': 'SSC JE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '58299138e624a0b7a8c85b7ae0c51a1f',
#     'title': [{'language': 'English', 'value': 'Defence Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'}]},
#  {'sid': '5806a74ccf97c88a63e9687e84a1f476',
#   'targets': [{'_id': '313f005f54973e4855569bcf06c70901',
#     'title': [{'language': 'English', 'value': 'NIC Technical Assistant A'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'},
#    {'_id': '31cde784a0638faea8011329b82e8c1f',
#     'title': [{'language': 'English', 'value': 'DSSSB'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'}]},
#  {'sid': 'fb847692eb0e5f65ee459987e7c72fd1',
#   'targets': [{'_id': '313f005f54973e4855569bcf06c70901',
#     'title': [{'language': 'English', 'value': 'NIC Technical Assistant A'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'},
#    {'_id': '31cde784a0638faea8011329b82e8c1f',
#     'title': [{'language': 'English', 'value': 'DSSSB'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'}]},
#  {'sid': '47aceefdcba6dfbd556201d1731ad933',
#   'targets': [{'_id': '313f005f54973e4855569bcf06c70901',
#     'title': [{'language': 'English', 'value': 'NIC Technical Assistant A'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'}]},
#  {'sid': 'f90f8b8147f19c81cbf39c9514b307ef',
#   'targets': [{'_id': '313f005f54973e4855569bcf06c70901',
#     'title': [{'language': 'English', 'value': 'NIC Technical Assistant A'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'}]},
#  {'sid': 'faf37b050bb1756cfb702228d96f9d2f',
#   'targets': [{'_id': '313f005f54973e4855569bcf06c70901',
#     'title': [{'language': 'English', 'value': 'NIC Technical Assistant A'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'},
#    {'_id': '31cde784a0638faea8011329b82e8c1f',
#     'title': [{'language': 'English', 'value': 'DSSSB'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'},
#    {'_id': '16a7a71a6e502baa03d4ae1faa5f33c8',
#     'title': [{'language': 'English', 'value': 'CDS'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'},
#    {'_id': 'e3982307901f966a3020ac8684652fdd',
#     'title': [{'language': 'English', 'value': 'SSC JHT'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '678e52493d6f118392a01f8883ad1a6a',
#     'title': [{'language': 'English', 'value': 'NBE'},
#      {'language': 'Hindi', 'value': 'NBE'}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '8dce41b95f3777d43d7ac6259bf1c39a',
#     'title': [{'language': 'English', 'value': 'IBPS PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '73a98d968ca9e75681a6b96a0877fa5d',
#     'title': [{'language': 'English', 'value': 'SSC JE CE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': 'd6424074fbe63ebc318dd438d724ae92',
#     'title': [{'language': 'English', 'value': 'Rajasthan Police Constable'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': 'b5dc7859e29e978c0c93d8592dd2a3c0',
#     'title': [{'language': 'English', 'value': 'SSC CHSL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '83178f9ff0a49d87094992bc13c744ed',
#     'title': [{'language': 'English', 'value': 'MP Patwari'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': 'f0cb553bd09b981f4dbca7c0890b108e',
#     'title': [{'language': 'English', 'value': 'Rajasthan Patwari'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '9819507ac598f457200e1c3656b73f6e',
#     'title': [{'language': 'English', 'value': 'IB ACIO Grade - II'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': 'e9fae828548a926b3b61cf0c83e611cc',
#     'title': [{'language': 'English', 'value': 'Rajasthan Police SI'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '13d3af1e81316b23d69de37fd93ea8f5',
#     'title': [{'language': 'English', 'value': 'RSMSSB JE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '5671296260527d58b8f0b38c79e1f774',
#     'title': [{'language': 'English', 'value': 'SSC JE EE'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '9ed77d9acfeaac2688e99b6e061b5873',
#     'title': [{'language': 'English', 'value': 'SSC JE ME'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': 'df9ebc68dc62a4a46f19a1e77209fba4',
#     'title': [{'language': 'English', 'value': 'Delhi Forest Guard'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': 'b81a8991dd18c0b47f6bc16c47dfa0ae',
#     'title': [{'language': 'English', 'value': 'SSC CGL'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '5c40422667cfdc719fe3f4d48130b34f',
#     'title': [{'language': 'English', 'value': 'SSC MTS'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '267449cef6a69ddba57803a44daea1fa',
#     'title': [{'language': 'English', 'value': 'RRB Officer Scale - I'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': 'a4b3f38ba5a80bc0ccb9d7e2be728229',
#     'title': [{'language': 'English', 'value': 'SBI PO'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'},
#    {'_id': '69b6d649ca5c4d3a10ae70ddd88ddcc8',
#     'title': [{'language': 'English', 'value': 'SSC Selection Post'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:19.565+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '58299138e624a0b7a8c85b7ae0c51a1f',
#     'title': [{'language': 'English', 'value': 'Defence Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '7c070251217c2bd79a08421d94e1fd37',
#     'title': [{'language': 'English', 'value': 'Teaching Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '09b12737a8cd173b05e9d16e456e8560',
#     'title': [{'language': 'English', 'value': 'Professional Skills'},
#      {'language': 'Hindi', 'value': 'व्यावसायिक कौशल'}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'c8acba07d96aadffb85deafafb4ff607',
#     'title': [{'language': 'English', 'value': 'Other Govt. Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'b44c28652d35c281b32c5dafb27ae341',
#     'title': [{'language': 'English', 'value': 'State Govt. Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '67bcbee6ffd1bf148fc2fb934d55f07e',
#     'title': [{'language': 'English', 'value': 'Railways Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '09b12737a8cd173b05e9d16e456e8560',
#     'title': [{'language': 'English', 'value': 'Professional Skills'},
#      {'language': 'Hindi', 'value': 'व्यावसायिक कौशल'}],
#     'updatedOn': '2020-08-31T22:01:57.394+05:30'}]},
#  {'sid': '76c2fe8bf0bba67b120d65b629b944c0',
#   'targets': [{'_id': '313f005f54973e4855569bcf06c70901',
#     'title': [{'language': 'English', 'value': 'NIC Technical Assistant A'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '58299138e624a0b7a8c85b7ae0c51a1f',
#     'title': [{'language': 'English', 'value': 'Defence Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '7c070251217c2bd79a08421d94e1fd37',
#     'title': [{'language': 'English', 'value': 'Teaching Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'}]},
#  {'sid': '4bef0d32488651b637022b4c692759fb',
#   'targets': [{'_id': '313f005f54973e4855569bcf06c70901',
#     'title': [{'language': 'English', 'value': 'NIC Technical Assistant A'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '58299138e624a0b7a8c85b7ae0c51a1f',
#     'title': [{'language': 'English', 'value': 'Defence Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '7c070251217c2bd79a08421d94e1fd37',
#     'title': [{'language': 'English', 'value': 'Teaching Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'}]},
#  {'sid': '4a01a1fb919b31ba68cf440d87bc08b8',
#   'targets': [{'_id': '313f005f54973e4855569bcf06c70901',
#     'title': [{'language': 'English', 'value': 'NIC Technical Assistant A'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'},
#    {'_id': '31cde784a0638faea8011329b82e8c1f',
#     'title': [{'language': 'English', 'value': 'DSSSB'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'},
#    {'_id': '16a7a71a6e502baa03d4ae1faa5f33c8',
#     'title': [{'language': 'English', 'value': 'CDS'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:03:21.376+05:30'}],
#   'target_super_groups': [{'_id': '4db3fc331f6c3cc1afcd4cb6938db9d0',
#     'title': [{'language': 'English', 'value': 'Banking Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '58299138e624a0b7a8c85b7ae0c51a1f',
#     'title': [{'language': 'English', 'value': 'Defence Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'b4079255a4b812351b0a98cc4f5ad675',
#     'title': [{'language': 'English', 'value': 'Police Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '7c070251217c2bd79a08421d94e1fd37',
#     'title': [{'language': 'English', 'value': 'Teaching Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'e992109a17e84f458f34c1b888c23205',
#     'title': [{'language': 'English', 'value': 'SSC Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '09b12737a8cd173b05e9d16e456e8560',
#     'title': [{'language': 'English', 'value': 'Professional Skills'},
#      {'language': 'Hindi', 'value': 'व्यावसायिक कौशल'}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'c1d47cdfe41a7ea2c337dd54c5114168',
#     'title': [{'language': 'English',
#       'value': 'Engineering Recruitment Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'c8acba07d96aadffb85deafafb4ff607',
#     'title': [{'language': 'English', 'value': 'Other Govt. Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': 'b44c28652d35c281b32c5dafb27ae341',
#     'title': [{'language': 'English', 'value': 'State Govt. Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'},
#    {'_id': '67bcbee6ffd1bf148fc2fb934d55f07e',
#     'title': [{'language': 'English', 'value': 'Railways Exams'},
#      {'language': 'Hindi', 'value': ''}],
#     'updatedOn': '2020-08-31T22:02:22.076+05:30'}]},
#  ...]
